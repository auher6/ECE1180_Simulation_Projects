# %% [markdown]
# <h1>Project 0: Installation and Tutorial

# %% [markdown]
# <h2>Import VPython

# %%
from vpython import *
# Out:
# C:\Users\auher\anaconda3\envs\myenv\lib\site-packages\vpython\__init__.py:1: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import get_distribution, DistributionNotFound
# <div id="glowscript" class="glowscript"></div>

# %% [markdown]
# <h2>Simulation Code

# %%
#Create a new canvas
scene = canvas()

#Ball object with base shape
ball = sphere(pos=vector(-5,0,0), radius=0.5, color=color.cyan, make_trail=True)

#Right and left green walls
wallR = box(pos=vector(6,0,0), size=vector(0.2,12,12), color=color.green)
wallL = box(pos=vector(-6,0,0), size=vector(0.2,12,12), color=color.green)

#Top and bottom blue walls
wallT = box(pos=vector(0,6,0), size = vector(12,0.2,12), color = color.blue)
wallB = box(pos=vector(0,-6,0), size = vector(12,0.2,12), color = color.blue)

#Red wall at the back
wallBack = box(pos=vector(0,0,-6), size = vector(12,12,0.2), color = color.red)

#Give the ball an x, y, and z velocity to demonstrate collision
ball.velocity = vector(25,5,15)

#Used in scaling the yellow arrow
vscale = 0.1

#Create a yellow arrow in position with the ball that points in the ball's direction
varr = arrow(pos=ball.pos, axis=vscale*ball.velocity, color=color.yellow)

#Update the time
deltat = 0.005
t = 0
scene.autoscale = False

#Three second simulation
while t < 3:
    #Must set rate always
    rate(100)

    #Checks for ball hitting a wall and bouncing off
    if ball.pos.x > wallR.pos.x:
        ball.velocity.x = -ball.velocity.x
    if ball.pos.x < wallL.pos.x:
        ball.velocity.x = -ball.velocity.x
    if ball.pos.y > wallT.pos.y:
        ball.velocity.y = -ball.velocity.y
    if ball.pos.y < wallB.pos.y:
        ball.velocity.y = -ball.velocity.y
    if ball.pos.z < wallBack.pos.z:
        ball.velocity.z = -ball.velocity.z
    if ball.pos.z > 6:
        ball.velocity.z = -ball.velocity.z

    #Update ball position, time, and arrow position/direction
    ball.pos = ball.pos + ball.velocity*deltat
    t = t + deltat
    varr.pos=ball.pos
    varr.axis = vscale*ball.velocity
# Out:
# <div id="glowscript" class="glowscript"></div>

# %% [markdown]
# <h2>Goals

# %% [markdown]
# <h3>a. Coding Background

# %% [markdown]
# I have done coding in many different languages at varying levels of expertise. I have used C, C++, C#, Python, Java, and JavaScript. I am most confident in C++, C#, and Python. I have two internships of software experience and am in my senior year, so I have experience utilizing these lagnuages in real projects.

# %% [markdown]
# <h3>b. Software knowledge I hope to gain

# %% [markdown]
# I hope to become better at python in general and to understand the other tools we will use better, like Jupyter notebooks, VPython, and others. I hope this class will allow me to understand how physical concepts can be modeled through code

# %% [markdown]
# <h3>c. What modeling and simulation concepts I hope to learn

# %% [markdown]
# I hope to gain a better idea of the steps taken in modeling physical systems, from specifying the requiements and rules to actual system design. I hope I will have a better understanding of how real simulation softwares are created and are run.

# %% [markdown]
# <h3>d. Systems and domain areas of interest

# %% [markdown]
# I am interested in gravitational physics and recreating smaller objects, like the lattice structure example. I think it will be interesting to see how accurate we can get to real world systems and learn about the limitations faced in these types of fields
